# %%
import xarray as xr

# %%
steric = xr.open_zarr('/swot/SUM02/spencer/steric_inc_mean.zarr').steric

# %%
steric_mean = steric.isel(time=slice(0,1751)).mean('time')

# %%
steric_mean.plot()
# Out:
# /home/spencerj/.conda/envs/pangeo1/lib/python3.9/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
steric_mean.to_dataset(name='steric').to_zarr('/swot/SUM02/spencer/swot_agulhas_surf/steric_mean.zarr')
# Out:
# /home/spencerj/.conda/envs/pangeo1/lib/python3.9/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
